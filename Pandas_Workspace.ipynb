# %%
import pandas as pd

# %%
df = pd.read_csv('data/developer_survey_2020/survey_results_public.csv')

# %%
schema_df = pd.read_csv('data/developer_survey_2020/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 100)

# %%
df.head(10)
# df.tail(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Grenada                                   1
# Micronesia, Federated States of...        1
# Lesotho                                   1
# Chad                                      1
# Kiribati                                  1
# Name: Country, Length: 183, dtype: int64

# %%
df.loc[0:2, 'Hobbyist':'Country']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country
# 0             Germany
# 1      United Kingdom
# 2  Russian Federation

# %%
high_salary_filter = (df['ConvertedComp'] > 70000)

# %%
north_america_filter = df['Country'].isin(['United States', 'Canada'])

# %%
valid_lan_filter = (~pd.isnull(df['LanguageWorkedWith']))

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df.loc[
    high_salary_filter & north_america_filter & valid_lan_filter, 
    ['Country', 'ConvertedComp', 'LanguageWorkedWith']
]
# Out:
#              Country  ConvertedComp  \
# 7      United States       116000.0
# 16     United States        79000.0
# 17     United States      1260000.0
# 18     United States        83400.0
# 25            Canada        71093.0
# ...              ...            ...
# 64013  United States       200000.0
# 64014  United States       250000.0
# 64035  United States      2000000.0
# 64057  United States      2000000.0
# 64058         Canada       151263.0
#
#                                       LanguageWorkedWith
# 7                                             Python;SQL
# 16                 C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 17                   Bash/Shell/PowerShell;HTML/CSS;Perl
# 18     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 25                                     JavaScript;Python
# ...                                                  ...
# 64013  C;C#;C++;Dart;Go;HTML/CSS;Kotlin;Python;TypeSc...
# 64014    Bash/Shell/PowerShell;C;C++;Go;Perl;Python;Ruby
# ...

# %%
# DataFrame is like Python Dictionary
students = {
    'name': ['Tanzim', 'Serhan', 'Fatiha'],
    'department': ['CSE', 'EEE', 'BBA'],
    'cgpa': [3.86, 2.93, 3.05]
}
students_df = pd.DataFrame(students)

# %%
students_df['name']
# Out:
# 0    Tanzim
# 1    Serhan
# 2    Fatiha
# Name: name, dtype: object

# %%
# Series is a column of a DataFrame
type(students_df['name'])
# Out:
# pandas.core.series.Series

# %%
students_df[0:2]
# Out:
#      name department  cgpa
# 0  Tanzim        CSE  3.86
# 1  Serhan        EEE  2.93

# %%
students_df.count()
# Out:
# name          3
# department    3
# cgpa          3
# dtype: int64

# %%
students_df[['cgpa', 'name']]
# Out:
#    cgpa    name
# 0  3.86  Tanzim
# 1  2.93  Serhan
# 2  3.05  Fatiha

# %%
students_df.columns
# Out:
# Index(['name', 'department', 'cgpa'], dtype='object')

# %%
# Search by Integer Location
students_df.iloc[[1, 2], [0, 2]]
# Out:
#      name  cgpa
# 1  Serhan  2.93
# 2  Fatiha  3.05

# %%
# Search by Label
students_df.loc[[1, 2], ['name', 'cgpa']]
# Out:
#      name  cgpa
# 1  Serhan  2.93
# 2  Fatiha  3.05

# %%
# Indexes - How to Set, Reset, and Use Indexes
students_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
students_df.set_index('cgpa', inplace=True)

# %%
students_df['name']
# Out:
# cgpa
# 3.86    Tanzim
# 2.93    Serhan
# 3.05    Fatiha
# Name: name, dtype: object

# %%
students_df.reset_index(inplace=True)

# %%
filt = (students_df['cgpa'] > 3.0) & (students_df['cgpa'] < 3.5)

# %%
students_df.loc[~filt]
# Out:
#    cgpa    name department
# 0  3.86  Tanzim        CSE
# 1  2.93  Serhan        EEE

# %%
students_df.loc[0, 'department'] = 'BSc CSE'

# %%
students_df.loc[0]
# Out:
# cgpa             3.86
# name           Tanzim
# department    BSc CSE
# Name: 0, dtype: object

# %%
# APPLY
students_df['department'].apply(lambda x: x.upper())
# Out:
# 0    BSC CSE
# 1        EEE
# 2        BBA
# Name: department, dtype: object

# %%
# APPLYMAP
students_df.applymap(lambda x: x.upper() if type(x) == str else x)
# Out:
#    cgpa    name department
# 0  3.86  TANZIM    BSC CSE
# 1  2.93  SERHAN        EEE
# 2  3.05  FATIHA        BBA

# %%
# MAP
students_df['name'].map({'Tanzim': 'Lupin'})
# Out:
# 0    Lupin
# 1      NaN
# 2      NaN
# Name: name, dtype: object

# %%
# REPLACE
students_df['name'] = students_df['name'].replace({'Tanzim': 'Lupin'})

# %%
students_df['id'] = [f'ID-{i}' for i in range(1, students_df.shape[0] + 1)]

# %%
students_df.drop(columns=['id'], inplace=True)

# %%
students_df
# Out:
#    cgpa    name department
# 0  3.86   Lupin    BSc CSE
# 1  2.93  Serhan        EEE
# 2  3.05  Fatiha        BBA

# %%
students_df = students_df.append({
    'name': 'Tom Hanks',
    'club': 'Sports'
}, ignore_index=True)

# %%
students_df
# Out:
#    cgpa       name department    club
# 0  3.86      Lupin    BSc CSE     NaN
# 1  2.93     Serhan        EEE     NaN
# 2  3.05     Fatiha        BBA     NaN
# 3   NaN  Tom Hanks        NaN  Sports

# %%
name_filter = students_df['nazme'] == 'Tom Hanks'
students_df.drop(index=3, inplace=True)

# %%
students_df
# Out:
#    cgpa    name department club
# 0  3.86   Lupin    BSc CSE  NaN
# 1  2.93  Serhan        EEE  NaN
# 2  3.05  Fatiha        BBA  NaN
